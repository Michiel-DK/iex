# %%
# Imports
from iexfinance.stocks import Stock
import requests
import urllib.parse
import requests
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import time
import seaborn as sns

# %%
# Set-up
period = 'quarter'
time = '24'
symbol = ["ADBE","CRM"]
token = 'Tsk_910a8ace8ad14af698bc4a65be1a4219'

# %%
dic = {}

def get_df(portfolio, period, time, token):
    for ticker in portfolio:
        financials_url = f"https://sandbox.iexapis.com/stable/stock/{ticker}/financials?period={period}&last={time}&token={token}"
        financials_json = requests.get(financials_url).json()
        dic[ticker] = pd.DataFrame(financials_json['financials'])

# %%
get_df(symbol,period,time,token)

# %%
dic['ADBE']
# Out:
#         EBITDA  accountsPayable capitalSurplus  cashChange    cashFlow  \
# 0   1295108233        319489886           None   742963074  5944560194
# 1   1142939127        233819009           None   925919574  4061996765
# 2   1083564111        301822926           None   186562320     2551370
# 3   1018686270        269779909           None    -6145620     1358848
# 4   1036151513        214319687           None   526524801  4577518847
# 5    935444997        191539566           None   177643769  3453193597
# 6    800938940        176268173           None   260118224  2312290006
# 7    748675672        147785636           None    -2736561  1135150143
# 8    783400713        188686515           None -1727349318  4139833755
# 9    756962842        149906153           None -1394831352  3155239992
# 10   750893013        119420368           None   187689219  2058720965
# 11   741444866        132731737           None   338485393  1013766786
# 12   676469322        116348142           None   456824724  3019136545
# 13   581682494         94799754           None   455012300  2207078592
# 14   526250179         79077696           None   293269207  1516085189
# 15   505412288        197793661           None  -115034797   745057924
# 16   493586053         88806811           None   320580502  2254838363
# 17   404443115         86496452           None   130359631  1698923902
# 18   375264694         75620453           None   230245309  1150719734
# 19   333077923         72676530           None   115197761   553280195
# 20   314640639         95519204           None   320890273  1502702859
# 21   268220156         72908406           None   267354111  1116566275
# 22   213588820         58923370           None   239158444   750209208
# 23   194650154         73848060           None  -564038045   368946962
#
#     cashFlowFinancing  changesInInventories  changesInReceivables  \
# 0         -3585918235                     0              81403745
# 1         -2597593458                     0             -49608322
# 2            -2205187                     0             -24131658
# 3            -1279517                     0            -152700322
# 4         -3079395250                     0             163456089
# 5         -2242617913                     0             101750618
# 6         -1506269330                     0             -70238360
# 7          -747797340                     0              27224942
# 8            -5831876                     0             282284680
# 9            -4295888                     0             -31270836
# 10           -2875127                     0              12577505
# 11           -1399722                     0            -156977377
# 12        -1216675606                     0             213734764
# 13         -899907125                     0             107039306
# 14         -602932589                     0              51293653
# 15         -305894499                     0              18487371
# 16        -1100699448                     0             106736218
# 17         -852547180                     0              65321268
# 18         -562220592                     0              68492466
# 19         -273801625                     0             -74455920
# 20         -205073283                     0              80707395
# 21         -154785742                     0              94120492
# 22         -105032259                     0             -30934033
# 23          -50766771                     0             -60031359
#
#     commonStock  costOfRevenue  ...   totalCash   totalDebt  \
# 0     490686709      439088333  ...  6108187852  4224940650
# 1     494450339      430471486  ...  5346728155  4150504805
# 2     488487579      428013908  ...  4417553852  4237835488
# 3     483973538      471946139  ...  4232929377  4210282469
# 4     501865576      471285524  ...  4258348531  4339692496
# 5     498717632      430097281  ...  3655869610  4340374616
# 13  SIANNLFCIA  EBDA  qrtalruye  1668929612460
# 14  CLIFAASINN  AEDB  qyalretru  1651086555204
# 15  CIAINALFNS  BEDA  tyuqearlr  1680047912492
# 16  LFSIAAICNN  BAED  qtrruyela  1675583467494
# 17  ANICNAFSIL  ADBE  ytrqelaru  1656069913072
# 18  ISLAFNCIAN  ABDE  rtlequyra  1651277992033
# 19  NNCLFIAASI  DABE  ertuqryal  1692313155022
# 20  ANFAIISCNL  EADB  qlutreayr  1645811595916
# 21  ALNSCNAFII  ADEB  rteqyrlua  1616280549244
# 22  ICAINSFNAL  EADB  qaeulryrt  1645670871733
# 23  AFICNIASNL  BDEA  rylurqeta  1669375909470
#
# [24 rows x 69 columns]

# %%
# URL set-up
income_url = f'https://sandbox.iexapis.com/stable/stock/{symbol}/income?period={period}&last={time}&token={token}'
cash_url = f'https://sandbox.iexapis.com/stable/stock/{symbol}/cash-flow?period={period}&last={time}&token=Tsk_910a8ace8ad14af698bc4a65be1a4219'
balance_url = f'https://sandbox.iexapis.com/stable/stock/{symbol}/balance-sheet?period={period}&last={time}&token=Tsk_910a8ace8ad14af698bc4a65be1a4219'
financials_url = f"https://sandbox.iexapis.com/stable/stock/{symbol}/financials?period={period}&last={time}&token=Tsk_910a8ace8ad14af698bc4a65be1a4219"
fundamentals_url = f"https://sandbox.iexapis.com/stable/time-series/fundamentals/{symbol}/{period}ly?range={time}q&token=Tsk_910a8ace8ad14af698bc4a65be1a4219"
stats_url = f"https://sandbox.iexapis.com/stable/stock/{symbol}/stats?token=Tsk_910a8ace8ad14af698bc4a65be1a4219"

# %%
# URL request
income = pd.DataFrame(requests.get(income_url).json()['income'])
cash = pd.DataFrame(requests.get(cash_url).json()['cashflow'])
balance = pd.DataFrame(requests.get(balance_url).json()['balancesheet'])
financials = pd.DataFrame(requests.get(financials_url).json()['financials'])
stats = requests.get(stats_url).json()

# %%
tables = [income,cash,balance,financials]

# %%
financials['merger'] = financials[['fiscalYear', 'fiscalQuarter']].astype('str').agg('-'.join, axis=1)

# %%
def lower_columns(ls):
    for table in ls:
        table.rename(str.lower, axis='columns', inplace=True)

# %%
def date_to_index(ls):
    for table in ls:
        table.set_index(pd.to_datetime(table['fiscaldate'].apply(lambda x: x[:7])), inplace=True)

# %%
lower_columns(tables)
date_to_index(tables)

# %%
cash.head()
# Out:
#             capitalexpenditures  cashchange    cashflow  cashflowfinancing  \
# fiscaldate
# 2020-11-01           -439049353   733295348  5799739459        -3554769652
# 2020-08-01           -326044418   932541030  4105398952        -2622258978
# 2020-05-01              -197798   185135512     2616194           -2195470
# 2020-02-01               -95350    -6007251     1330621           -1239194
# 2019-11-01           -410566231   537349704  4432665363        -2991602371
#
#             changesininventories  changesinreceivables currency  depreciation  \
# fiscaldate
# 2020-11-01                     0              83093927      USD     766307393
# 2020-08-01                     0             -48857393      USD     584349030
# 2020-05-01                     0             -23201888      USD        377932
# 2020-02-01                     0            -149576038      USD        191632
# 2019-11-01                     0             170526693      USD     763518515
#
#            dividendspaid exchangerateeffect  ... netborrowings   netincome  \
# fiscaldate                                   ...
# 2020-11-01          None               None  ...   -2666312032  2259556293
# 2020-08-01          None               None  ...   -1968817585   970847628
# 2020-05-01          None               None  ...   -1226149173  1131220771
# 2020-02-01          None               None  ...    -954076294  1002128358
# 2019-11-01          None               None  ...    -854873879   862181129
#
#             otherfinancingcashflows  reportdate symbol  \
# fiscaldate
# 2020-11-01                     None  2021-01-04   ADBE
# 2020-08-01                     None  2020-09-18   ADBE
# 2020-05-01                     None  2020-06-09   ADBE
# 2020-02-01                     None  2020-03-13   ADBE
# 2019-11-01                     None  2020-01-12   ADBE
#
#            totalinvestingcashflows         id   key     subkey        updated
# fiscaldate
# 2020-11-01              -416592335  CHOAWFSL_  EDBA  ratlryque  1661840063085
# 2020-08-01              -296993167  SFOHW_CLA  EABD  luqayerrt  1621056657020
# 2020-05-01                   32606  _SHFCOWAL  ABDE  eyrqualrt  1636144965124
# 2020-02-01                  -48774  HCSLFAOW_  BEDA  qylreurta  1661592379403
# 2019-11-01              -476695954  CFWOL_AHS  DEAB  ytqareurl  1633774136320
#
# [5 rows x 26 columns]

# %%
# Collection table
collection = pd.DataFrame()
collection = financials[['revenue','netincome','operatingincome','cashflow','ebitda','totalassets','totalcash','totaldebt','shareholderequity','merger']]
cash['fcf'] = cash.loc[:,'cashflow'] - cash.loc[:,'capitalexpenditures']
collection = collection.merge(cash['fcf'], left_index=True,right_index=True)

# %%
collection_q = collection.copy()
collection_q['time'] = 'q'
collection_y = collection.groupby(pd.Grouper(freq='y')).agg({'revenue':'sum', 'netincome':'sum', 'operatingincome':'sum'})
collection_y['time'] = 'y'

# %%
def add_profitability(df):
    df['operating_margin'] = df['operatingincome'] / df['revenue']
    df['net_margin'] = df['netincome'] / df['revenue']
    df['asset_turnover'] = df['revenue'] / df['totalassets']
    df['roa'] = df['netincome']*4/ df['totalassets']
    df['equity_multipl'] = df['totalassets'] / df['shareholderequity']
    df['roe'] = df['netincome'] / df['shareholderequity']
    df['fcf_margin'] = df['fcf'] / df['revenue']

# %%
def add_financial_strength(df):
    df['cash_debt'] = df['totalcash'] / df['totaldebt']
    df['equity_asset'] = df['shareholderequity'] / df['totalassets']
    df['debt_equity'] = df['totaldebt'] / df['shareholderequity']
    df['debt_ebitda'] = df['totaldebt'] / (df['ebitda']*4)

# %%
add_profitability(collection_q)
add_financial_strength(collection_q)

# %%
collection_q.columns
# Out:
# Index(['revenue', 'netincome', 'operatingincome', 'cashflow', 'ebitda',
#        'totalassets', 'totalcash', 'totaldebt', 'shareholderequity', 'merger',
#        'fcf', 'time', 'operating_margin', 'net_margin', 'asset_turnover',
#        'roa', 'equity_multipl', 'roe', 'fcf_margin', 'cash_debt',
#        'equity_asset', 'debt_equity', 'debt_ebitda'],
#       dtype='object')

# %%
plt.plot(collection_q[['revenue','netincome']])
# Out:
# [<matplotlib.lines.Line2D at 0x11b4daa50>,
#  <matplotlib.lines.Line2D at 0x11b4c3810>]

# %%
plt.plot(collection_q[['operatingincome','fcf','netincome']])
# Out:
# [<matplotlib.lines.Line2D at 0x11d545a90>,
#  <matplotlib.lines.Line2D at 0x11d5d4a50>,
#  <matplotlib.lines.Line2D at 0x11d5f9210>]
